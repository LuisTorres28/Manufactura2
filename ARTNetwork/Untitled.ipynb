# %%
# %run ART_Network.py
# Out:
# | 0 | 0.100 | 5 | 2 |
# | 0 | 0.300 | 5 | 2 |
# | 0 | 0.500 | 5 | 2 |
# | 0 | 0.700 | 5 | 3 |
# | 0 | 0.900 | 5 | 4 |
# | 0 | 0.999 | 5 | 4 |
# | 1 | 0.100 | 5 | 2 |
# | 1 | 0.300 | 5 | 2 |
# | 1 | 0.500 | 5 | 2 |
# | 1 | 0.700 | 5 | 3 |
# | 1 | 0.900 | 5 | 4 |
# | 1 | 0.999 | 5 | 5 |
# | 2 | 0.100 | 10 | 4 |
# | 2 | 0.300 | 10 | 4 |
# | 2 | 0.500 | 10 | 5 |
# | 2 | 0.700 | 10 | 6 |
# | 2 | 0.900 | 10 | 8 |
# | 2 | 0.999 | 10 | 10 |
# | 3 | 0.100 | 11 | 4 |
# | 3 | 0.300 | 11 | 4 |
# C:\Users\latm_\Desktop\Luis_Angel_Torres_Martinez\Maestria Robotica\Manufactura_2\Tareas\Manufactura2\ARTNetwork\ART_Network.py:31: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(constrained_layout=True)
# | 3 | 0.500 | 11 | 4 |
# | 3 | 0.700 | 11 | 6 |
# ...
